# %% [markdown]
# # HW 2
#
# Daniel Sevilla
#
# CSC310 HW2
#
# 9-10-25
#
# ### Assigment Directions
# Find 2 different data sets and compute summary statistics.
#
# For each data set try to answer the following questions:
#
# - How many columns are there?
# - How many rows are there?
# - Are the columns numerical, categorical, or both?
# - Are there columns that provide no information? Just constant or unique values for all observations.
# - For each categorical columns compute the mode.
# - For each numerical column compute the mean (average), max, and min values.
# Plot histograms for numerical columns -- comment on the distribution (normal, multi-modal etc)
# - Plot bar plots for categorical columns. -- comment on whether the data set is balanced in terms of the representation of the various labels in the categorical columns.

# %%
import pandas as pd

FireDT = pd.read_csv("https://raw.githubusercontent.com/DanielS129/URI-CSC310/refs/heads/main/Assignments/HW2/forestfires.csv")
GunsDT = pd.read_csv("https://raw.githubusercontent.com/DanielS129/URI-CSC310/refs/heads/main/Assignments/HW2/Guns.csv")

# %% [markdown]
# ## Description
# The first Data set can be found from UCI Dataset. https://archive.ics.uci.edu/dataset/162/forest+fires
#
# "This is a difficult regression task, where the aim is to predict the burned area of forest fires, in the northeast region of Portugal, by using meteorological and other data"
#
# The second Data set was found from R Dataset. Here is the Document, https://vincentarelbundock.github.io/Rdatasets/doc/dslabs/murders.html
#
# "Gun murder data from FBI reports. Also contains the population of each state."

# %%
FireDT.shape
# Out:
# (517, 13)

# %%
GunsDT.shape
# Out:
# (1173, 14)

# %% [markdown]
# ## How many Columns and Rows are there?
# To find the Collums and Rows, Here shape displays (x,y) where X is Rows and Y is Collums
# - Forest Fire Data set has 517 Rows and 13 Collums
#  - Gun Data Set has 1173 Rows and 14 Collums

# %%
FireDT.head(3)
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0

# %%
GunsDT.head(3)
# Out:
#    rownames  year  violent  murder  robbery  prisoners      afam      cauc  \
# 0         1  1977    414.4    14.2     96.8         83  8.384873  55.12291
# 1         2  1978    419.1    13.3     99.1         94  8.352101  55.14367
# 2         3  1979    413.3    13.2    109.5        144  8.329575  55.13586
#
#        male  population    income   density    state law
# 0  18.17441    3.780403  9563.148  0.074552  Alabama  no
# 1  17.99408    3.831838  9932.000  0.075567  Alabama  no
# 2  17.83934    3.866248  9877.028  0.076245  Alabama  no

# %% [markdown]
# ## Are the columns numerical, categorical, or both?
# Here we will use the .head() to show the first 3 rows of each dataset.
#
# For the Forest Fire dataset we can see that there is a mix of both numerical Collums such as X, Y and Categorical Collums such as Month, Day
#
# For the Guns Dataset we can see that there is both Categorical such as Law and State, and Numerical such as Population and Prisoners.

# %%
FireDT.nunique()
# Out:
# X          9
# Y          7
# month     12
# day        7
# FFMC     106
# DMC      215
# DC       219
# ISI      119
# temp     192
# RH        75
# wind      21
# rain       7
# area     251
# dtype: int64

# %%
GunsDT.nunique()
# Out:
# rownames      1173
# year            23
# violent       1101
# murder         184
# robbery        947
# prisoners      436
# afam          1173
# cauc          1173
# male          1173
# population    1173
# income        1170
# density       1173
# state           51
# law              2
# dtype: int64

# %% [markdown]
# ## Are there columns that provide no information? Just constant or unique values for all observations.
#
# For the Forest Fire Dataset it doesnt not have either constant or FULLY unique values, it does have unique collums for the whole dataset
#
# For the Guns Dataset it does not have any constant Values but does have Fully Unique Values for example for Population and Density. While the rest are just normal unique Values.

# %%
FireDT["month"].mode()
# Out:
# 0    aug
# Name: month, dtype: object

# %%
FireDT["day"].mode()
# Out:
# 0    sun
# Name: day, dtype: object

# %%
GunsDT["state"].mode()
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
GunsDT["law"].mode()
# Out:
# 0    no
# Name: law, dtype: object

# %% [markdown]
# ## For each categorical columns compute the mode.
#
# ### Forest Fire
# Forest fire dataset has 2 Categorical Collums, which are Month and day
# - Month has a mode of August
# - Day has a mode of Sun
# ### Guns
# Guns Data set has 2 Categorical Collums, which are State and Law
# - State Returns all 50 states as they all appear the same amount of times
# - Law has a mode of No

# %%
FireDT.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
FireDT.hist()
# Out:
# array([[<Axes: title={'center': 'X'}>, <Axes: title={'center': 'Y'}>,
#         <Axes: title={'center': 'FFMC'}>],
#        [<Axes: title={'center': 'DMC'}>, <Axes: title={'center': 'DC'}>,
#         <Axes: title={'center': 'ISI'}>],
#        [<Axes: title={'center': 'temp'}>, <Axes: title={'center': 'RH'}>,
#         <Axes: title={'center': 'wind'}>],
#        [<Axes: title={'center': 'rain'}>,
#         <Axes: title={'center': 'area'}>, <Axes: >]], dtype=object)

# %%
GunsDT.describe()
# Out:
#          rownames         year      violent       murder      robbery  \
# count  1173.00000  1173.000000  1173.000000  1173.000000  1173.000000
# mean    587.00000  1988.000000   503.074680     7.665132   161.820205
# std     338.76024     6.636079   334.277194     7.522710   170.509962
# min       1.00000  1977.000000    47.000000     0.200000     6.400000
# 25%     294.00000  1982.000000   283.100000     3.700000    71.100000
# 50%     587.00000  1988.000000   443.000000     6.400000   124.100000
# 75%     880.00000  1994.000000   650.900000     9.800000   192.700000
# max    1173.00000  1999.000000  2921.800000    80.600000  1635.100000
#
#          prisoners         afam         cauc         male   population  \
# count  1173.000000  1173.000000  1173.000000  1173.000000  1173.000000
# mean    226.579710     5.336217    62.945432    16.081127     4.816341
# std     178.888094     4.885688     9.761527     1.732143     5.252115
# ...

# %%
GunsDT.hist()
# Out:
# array([[<Axes: title={'center': 'rownames'}>,
#         <Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'violent'}>],
#        [<Axes: title={'center': 'murder'}>,
#         <Axes: title={'center': 'robbery'}>,
#         <Axes: title={'center': 'prisoners'}>],
#        [<Axes: title={'center': 'afam'}>,
#         <Axes: title={'center': 'cauc'}>,
#         <Axes: title={'center': 'male'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'income'}>,
#         <Axes: title={'center': 'density'}>]], dtype=object)

# %% [markdown]
# ## For each numerical column compute the mean (average), max, and min values. Plot histograms for numerical columns -- comment on the distribution (normal, multi-modal etc)
#
# To Find the the mean, max and min Values for the Numberical Collums of each dataset we can use .describe to show us each colluma and their count, mean, standard Deviation, min, 25%, 50%, 75% and Max Vlaues.
#
# To View the values we can then use .hist() to display histograms for each collum.
#
# ### Forest Fire
# For the Forest fire dataset we can see that many of the histograms have either a normal, or bimodal distributions
# ### Guns
# For the Guns Dataset we can see that there are most of the histograms are normal or multimodal with an addition of 1 histogram being almost uniform.

# %%
FireDT["month"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
FireDT["day"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='day'>

# %%
GunsDT["state"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %%
GunsDT["law"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='law'>

# %% [markdown]
# ## Plot bar plots for categorical columns. -- comment on whether the data set is balanced in terms of the representation of the various labels in the categorical columns.
#
# TO then display A plot for the Categorical Collums we would then do
#
# date_set["CollumName"] which would grab that collum, after we put .value_counts() which then will show all the values for that collum and how many times it appears, and lastly we would then put .plot(kind='bar') to then plot those values onto a bar graph.
#
# ### Forest Fire
# - Month - Here the month plot is not balanced as we see a clear Skew
# - Day - Here we can see that its also not balanced, but its more harder to say here since the plots are close to eachother but still all in all aren't relatively close.
# ### Guns
# - State - Here we can see it clearly balanced, Its actually perfectly balanced
# - Law - Here we can see it not balanced with the 2 values having 600 value differnce.
